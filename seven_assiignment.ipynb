# %% [markdown]
# #Q1. Problem Statement
# Create an image gallery using a CSS grid
#
# - ans:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Document</title>
#     <style>
#         body{
#             background-color: whitesmoke;
#         }
#         .container{
#             display: grid;
#             grid-template-columns: repeat(3, 1fr);
#             grid-template-rows: repeat(3, 200px);
#             grid-gap: 10px;
#             width: 60%;
#             height: auto;
#             margin: auto;
#             padding: 20px;
#             border-radius: 10px;
#             background-color: white;
#             box-shadow: rgba(50, 50, 93, 0.25) 0px 50px 100px -20px, rgba(0, 0, 0, 0.3) 0px 30px 60px -30px;
#         }
#        .box1{
#             grid-column:1/3;
#         }
#         .box4{
#            grid-row:2/4;
#         }
#         .box6{
#             grid-column:3/3;
#             grid-row: 4/2;
#         }
#         img{
#             width: 100%;
#             height: 100%;
#             border-radius: 20px;
#             box-shadow: rgba(0, 0, 0, 0.16) 0px 10px 36px 0px, rgba(0, 0, 0, 0.06) 0px 0px 0px 1px;
#         }
#       </style>
# </head>
# <body>
#     <div class="container">
#         <div class="box box1"><img src="https://static.vecteezy.com/system/resources/thumbnails/006/240/302/small_2x/abstract-soft-focus-sunset-field-landscape-of-yellow-flowers-and-grass-meadow-warm-golden-hour-sunset-sunrise-time-tranquil-spring-summer-nature-closeup-and-blurred-forest-background-idyllic-nature-photo.jpg" alt=""></div>
#         <div class="box box2"><img src="https://bsmedia.business-standard.com/_media/bs/img/article/2015-09/11/full/1441979073-449.jpg?im=FeatureCrop,size=(826,465)" alt=""></div>
#         <div class="box box3"><img src="https://static.vecteezy.com/system/resources/thumbnails/006/240/302/small_2x/abstract-soft-focus-sunset-field-landscape-of-yellow-flowers-and-grass-meadow-warm-golden-hour-sunset-sunrise-time-tranquil-spring-summer-nature-closeup-and-blurred-forest-background-idyllic-nature-photo.jpg" alt=""></div>
#         <div class="box box4"><img src="https://m.media-amazon.com/images/I/71+17bVYHxL._AC_UF1000,1000_QL80_.jpg" alt=""></div>
#         <div class="box box5"><img src="https://cdn.britannica.com/76/82676-050-E95B5C00/nurses-patients-care-procedures.jpg?w=400&h=300&c=crop" alt=""></div>
#         <div class="box box6"><img src="https://m.media-amazon.com/images/I/81-Td-bcOVL._AC_UF1000,1000_QL80_.jpg" alt=""></div>
#
#     </div>
# </body>
# </html>

# %% [markdown]
# #Q2.Problem Statement  Write code to arrange containers with texts A, B, C, and D as shown in the below image
#
# - Ans :
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Document</title>
#     <style>
#         body{
#             background-color: whitesmoke;
#         }
#         .container{
#             display: grid;
#             background-color: white;
#             grid-template-columns: repeat(3, 1fr);
#             grid-template-rows: repeat(2,100px);
#             grid-gap: 10px;
#             width: 35%;
#             margin: 50px auto;
#             /* border: 1px solid black; */
#             padding: 20px;
#             border-radius: 10px;
#             box-shadow: rgb(38, 57, 77) 0px 20px 30px -10px;
#         }
#         .box{
#             /* border: 1px solid red; */
#             text-align: center;
#             display: flex;
#             justify-content: center;
#             align-items: center;
#             border-radius: 10px;
#             background-color: rgb(222, 185, 117);
#             opacity: 0.9;
#
#         }
#         .box-1{
#             grid-column: 1/3;
#         }
#         .box-2{
#             grid-column: 3/3;
#             grid-row:1/3;
#         }
#     </style>
# </head>
# <body>
#     <div class="container">
#     <div class="box box-1">A</div>
#     <div class="box box-2">B</div>
#     <div class="box box-3">C</div>
#     <div class="box box-4">D</div>
#
#     </div>
# </body>
# </html>

# %% [markdown]
# # Q3. Problem Statement  Explain the use of grid-auto-row and grid-auto-column using code examples.
#  - Ans :
#
# **grid-auto-rows**
# The grid-auto-rows property specifies the size of rows that are created implicitly. This is useful when you have more items than the explicitly defined rows.
# **grid-auto-columns**
# The grid-auto-columns property specifies the size of columns that are created implicitly. This is useful when you have more items than the explicitly defined columns.
#
# example: -
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Grid Auto Rows and Columns Example</title>
#     <style>
#         .grid-container {
#             display: grid;
#             grid-template-rows: repeat(2,100px);
#             grid-template-columns: 100px 100px;
#             grid-auto-rows:150px ; /*this is grid auto rows and without this line items5 items6 items7 items8 not applay row size  */
#             grid-auto-columns: 200px;
#             gap: 10px; /*Gap between grid items */
#         }
#
#         .grid-item {
#             background-color: #f0f0f0;
#             border: 1px solid #ccc;
#             padding: 20px;
#             text-align: center;
#         }
#     </style>
# </head>
# <body>
#
# <div class="grid-container">
#     <div class="grid-item">Item 1</div>
#     <div class="grid-item">Item 2</div>
#     <div class="grid-item">Item 3</div>
#     <div class="grid-item">Item 4</div>
#     <div class="grid-item">Item 5</div>
#     <div class="grid-item">Item 6</div>
#     <div class="grid-item">Item 7</div>
#     <div class="grid-item">Item 8</div>
# </div>
#
# </body>
# </html>

# %% [markdown]
# # Q4 Problem Statement  Write CSS to show numbers as shown in the figure, without altering the below html code.
# - ans :
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Document</title>
#     <style>
#         body{
#             display: flex;
#             align-items: center;
#             justify-content: center;
#             height: 100vh;
#         }
#         .container{
#             width: 50%;
#             background-color: whitesmoke;
#             display: grid;
#             grid-template-columns: repeat(6,1fr);
#             grid-template-rows: repeat(2,100px);
#             grid-gap: 10px;
#             padding: 20px;
#             border-radius: 10px;
#             box-shadow: rgba(0, 0, 0, 0.24) 0px 3px 8px;
#         }
#         .box{
#             border-radius: 10px;
#             display: flex;
#             align-items: center;
#             justify-content: center;
#             color: white;
#             font-size: 30px;
#         }
#         .box1{
#             background-color: rgb(53, 54, 55);
#             grid-row: 2/3;
#         }
#         .box2{
#             background-color: rgb(151, 154, 156);
#             grid-row: 2/3;
#         }
#         .box3{
#             background-color: rgb(53, 54, 55);
#         }
#         .box4{
#             background-color: rgb(151, 154, 156);
#         }
#         .box5{
#             background-color: rgb(53, 54, 55);
#         }
#         .box6{
#             background-color: rgb(151, 154, 156);
#         }
#         .box7{
#             background-color: rgb(53, 54, 55);
#         }
#         .box8{
#             background-color: rgb(151, 154, 156);
#         }
#     </style>
# </head>
# <body>
#     <div class="container">
#         <div class="box box1">1</div>
#         <div class="box box2">2</div>
#         <div class="box box3">3</div>
#         <div class="box box4">4</div>
#         <div class="box box5">5</div>
#         <div class="box box6">6</div>
#         <div class="box box7">7</div>
#         <div class="box box8">8</div>
#     </div>
# </body>
# </html>

# %% [markdown]
# # Q5 Problem Statement Explain the difference between justify-items and justify-self using code examples.
#
# - ans :
#
# In CSS Grid Layout, both justify-items and justify-self are used to control the alignment of grid items along the inline (row) axis, but they serve different purposes and scopes.
#
# **justify-items**
# It sets the default alignment for all grid items along the inline axis horizontal alignment in a left-to-right layout).
#
# **justify-self**
# Purpose: It allows you to override the default alignment set by justify-items for a specific grid item.
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Justify Items vs Justify Self Example</title>
#     <style>
#         .grid-container {
#             display: grid;
#             grid-template-columns: repeat(3, 100px);
#             grid-template-rows: repeat(2, 100px);
#             gap: 10px;
#             justify-items: center; /* Default alignment for all items */
#         }
#
#         .grid-item {
#             background-color: #f0f0f0;
#             border: 1px solid #ccc;
#             padding: 20px;
#             text-align: center;
#         }
#
#         .item1 {
#             justify-self: start; /* Override default alignment for this item */
#         }
#
#         .item2 {
#             justify-self: end; /* Override default alignment for this item */
#         }
#
#         .item3 {
#             justify-self: stretch; /* Override default alignment for this item */
#         }
#     </style>
# </head>
# <body>
#
# <div class="grid-container">
#     <div class="grid-item item1">Item 1</div>
#     <div class="grid-item item2">Item 2</div>
#     <div class="grid-item item3">Item 3</div>
#     <div class="grid-item">Item 4</div>
#     <div class="grid-item">Item 5</div>
#     <div class="grid-item">Item 6</div>
# </div>
#
# </body>
# </html>
